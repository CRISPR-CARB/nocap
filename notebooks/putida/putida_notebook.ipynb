# %%
import nocap.utility as utility
import networkx as nx

# %%
putida_graph = utility.parse_regulation_file("PPUT160488-regulatory-network.txt")
# Out:
# /Users/geor228/Github/nocap/src/nocap/utility.py:54: UserWarning: regulatee: aldB-I has no polarity
#   warnings.warn(f"regulatee: {regulatee} has no polarity")
# /Users/geor228/Github/nocap/src/nocap/utility.py:54: UserWarning: regulatee: alg44 has no polarity
#   warnings.warn(f"regulatee: {regulatee} has no polarity")
# /Users/geor228/Github/nocap/src/nocap/utility.py:54: UserWarning: regulatee: alg8 has no polarity
#   warnings.warn(f"regulatee: {regulatee} has no polarity")
# /Users/geor228/Github/nocap/src/nocap/utility.py:54: UserWarning: regulatee: algA has no polarity
#   warnings.warn(f"regulatee: {regulatee} has no polarity")
# /Users/geor228/Github/nocap/src/nocap/utility.py:54: UserWarning: regulatee: algD has no polarity
#   warnings.warn(f"regulatee: {regulatee} has no polarity")
# /Users/geor228/Github/nocap/src/nocap/utility.py:54: UserWarning: regulatee: algE has no polarity
#   warnings.warn(f"regulatee: {regulatee} has no polarity")
# ...

# %%
putida_grn_filename = "putida_grn.graphml"
nx.write_graphml(putida_graph,putida_grn_filename)
